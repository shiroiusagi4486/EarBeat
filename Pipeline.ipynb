# %% [markdown]
# # Librerias

# %%
#Librerias a utilizar
import requests
import re
from bs4 import BeautifulSoup
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy.oauth2 as oauth2
import pandas as pd
from pandas.io.json import json_normalize
import json
print('beatscrap importado')

# Modelo de Machine Learning
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
from numpy import genfromtxt
from scipy.cluster.hierarchy import cophenet
from scipy.spatial.distance import pdist
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans
print('librerias de clusterizacion y machine learning cargadas')

#lectura de pulso cardiaco
import serial
import time
print('Fingerbeat importado y sanito')

#presentacion de la recomendación de cluster
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.firefox_binary import FirefoxBinary
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities

print('Earbeat ensamblado')
# Out:
# beatscrap importado
# librerias de clusterizacion y machine learning cargadas
# Fingerbeat importado y sanito
# Earbeat ensamblado

# %% [markdown]
# # Beatscrap

# %%
# # Web scraping
def paginas():
    urls=[]
    while True:
        entrada = input("Hola, introduce el link de tu enlace de perfil de spotify, puedes introducir cualquier otra cosa para salir")
        if 'https://open.spotify.com/user/' in entrada:
            urls.append(entrada)
        else:
            break
    html =[requests.get(url).content for url in urls]
    usrs =[re.findall(r'\w*(?=\?)', url) for url in urls]
    usuariosID = [elemento[0] for elemento in usrs]
    playlists = [re.findall(r'\/playlist\/\w*', str(pagina)) for pagina in html]
    soups = [BeautifulSoup(pagina, 'lxml') for pagina in html]
    az = [soup.find_all('span',{'dir':'auto'}) for soup in soups]
    PlstName=[]
    nombres = []
    for etiquetas in az:
        limpio =[]
        for contenido in etiquetas:
            limpio.append(str(contenido).replace('<span dir="auto">', '').replace('</span>', ''))
        nombres.append(limpio[0])
        PlstName.append(limpio[1:])
    print('Obteniendo datos, no desesperes')
    listota = []
    diccionario = {}
    comprimido = zip(usuariosID, nombres, PlstName,playlists)
    for rar in comprimido:
        for p in range(len(rar[2])):
            diccionario= {'Id_usr':rar[0], 'Nombre_perfil':rar[1], 'PlaylistName':rar[2][p] ,'Id_playlist':rar[3][p]}
            listota.append(diccionario.copy())
    scrapdf = pd.DataFrame(listota)
    scrapdf.to_csv("./UsrPlay.csv", index = False)
    print('Scrap de paginas terminado, gracias por tus datos')
    return scrapdf

# %%
# # API Parsing
def musical(scrapdf):
    print('Hola nos estamos conectando a la API de Spotify')
    print('Espero no tardar con la obtencion de canciones de la lista que me has mandado, asi que no desesperes')
    CLIENT_ID = "2b7f57a2e7d74e43b0a0771a99fbb470"
    CLIENT_SECRET = "219cfd4ed31349d5b3175e3526de4921"

    credentials = oauth2.SpotifyClientCredentials(
            client_id=CLIENT_ID,
            client_secret=CLIENT_SECRET)

    token = credentials.get_access_token()
    spotify = spotipy.Spotify(auth=token)

    apiDF = pd.DataFrame({'href':[], 'items':[], 'limit':[], 'next':[], 'offset':[], 'previous':[], 'total':[]})
    dataframes = []
    for row in scrapdf.itertuples():
        canciones = spotify.user_playlist_tracks(row.Id_usr, str(row.Id_playlist).replace('/playlist/', ''))
        dataframes.append(pd.DataFrame(canciones))
    print('He terminado con obtención de canciones')
    apiDF = pd.concat(dataframes)
    apiDF.reset_index(inplace = True)
    candionero2 = json_normalize(apiDF['items'])
    dfinal = candionero2[['track.name', 'track.external_urls.spotify', 'track.href', 'track.id'  ,'track.popularity']]
    dfinal.drop_duplicates(inplace = True)
    dfinal.dropna(inplace = True)
    dfinal.to_csv("./SpotifyApi.csv", index = False)
    return dfinal

# %%
#Caracteristicas de las canciones estraidas directo del API de spotify
def caracteristicas(dfinal):
    CLIENT_ID = "2b7f57a2e7d74e43b0a0771a99fbb470"
    CLIENT_SECRET = "219cfd4ed31349d5b3175e3526de4921"

    credentials = oauth2.SpotifyClientCredentials(
            client_id=CLIENT_ID,
            client_secret=CLIENT_SECRET)

    token = credentials.get_access_token()
    spotify = spotipy.Spotify(auth=token)
    
    print('Comenzando con la obtencion de caracteristicas de cada canción de tus listas')
    df = pd.DataFrame(columns=['danceability',
                               'energy',
                               'key',
                               'loudness',
                               'mode',
                               'speechiness',
                               'acousticness',
                               'instrumentalness',
                               'liveness',
                               'valence',
                               'tempo',
                               'type',
                               'id',
                               'uri',
                               'track_href',
                               'analysis_url',
                               'duration_ms',
                               'time_signature'])
    
    n=0
    for ide in dfinal['track.id']: 
        elemento = spotify.audio_features(ide)
        anexado = pd.DataFrame(elemento[0].values())
        anexado = anexado.T
        anexado.columns = elemento[0].keys()
        df =df.append(anexado)
        n+=1
        print('Elemento:', n, ' de ', len(dfinal['track.id']))
    print('Obtencion de características Terminada, muchas gracias por tu paciencia')

    df.to_csv("./caracteristicas.csv", index = False)
    print('Fin de BEATSCRAP')
    return df

# %% [markdown]
# # Earlearning

# %%
#Construccion del modelo Para machine learning
def modeloreja(csv):
    modelo = csv.drop(columns = ['type', 'uri', 'track_href', 'analysis_url', 'duration_ms','time_signature'], axis = 1)
    modelo.reset_index(inplace = True)
    modelo.set_index('id', inplace = True)
    modelo = modelo.astype('float64')
    return modelo

# %%
#gráfico de dendograma y KElbow ilustrativos
def dendo(modelo):
    dendogram = modelo.copy()
    weighted = linkage(dendogram, method='weighted')

    print('weighted')
    fig = plt.figure(figsize=(25, 10))
    weightedplt = dendrogram(
        weighted,
        truncate_mode = 'lastp',
        p=12)
    plt.show()

    calinski_harabasz = KMeans()
    visualizer = KElbowVisualizer(calinski_harabasz, k=(2, 20), metric='calinski_harabasz')
    visualizer.fit(weighted)
    visualizer.poof();

# %%
#Clusterizacion y entrenamiento del modelo usando kmeans, tambien imprimimos metricas ilustrativas
def kmean(modelo):
    meansK12 = modelo.copy()
    kmeans12 = KMeans(n_clusters=25)
    spoty_clusters12 = kmeans12.fit(meansK12)
    print('Centros')
    print(spoty_clusters12.cluster_centers_)
    print()
    #predicciones para el modelo
    predictions12 = spoty_clusters12.fit_predict(meansK12)
    print('Predicciones')
    print(predictions12)
    print()
    #Distancias entre cada prediccion
    distances12 = spoty_clusters12.fit_transform(meansK12)
    print('Distancias')
    print(distances12)
    #creamos nueva columna con las predicciones 
    meansK12['Cluster12'] = predictions12
    meansK12.reset_index(inplace = True)
    meansK12.to_csv("./clusterizado.csv", index = False)
    #agrupamos el dataframe pormedio de la columna cluster12, y usamos el promedio del tempo, para crear una serie
    serie = meansK12.groupby(['Cluster12'])['tempo'].mean()
    return serie, meansK12

# %% [markdown]
# # FingerBeat

# %%
#lectura e impresion de pulsos desde el dedo
def dedito():
    print('Comenzaremos a recolectar algunas lecturas de frecuencia cardiaca, si no se recolectan, es debido a que algo interfiere con nuestra lectura')
    arduino = serial.Serial('COM3', 9600)
    time.sleep(2)
    pulsos = np.array([], dtype = float)
    n=0

    while n <5000:
        try:
            a = float(arduino.readline())
            if a>= 60.0 and a<=200.0:
                print('pulso: ',n , 'leido: ' ,a)
                pulsos = np.append(pulsos, a)
                n+=1
        except:
            pass
    print('Lectura Finalizada, muchas gracias por esperar')
    return pulsos.mean()

# %% [markdown]
# # Earbeat

# %%
#Generacion de recomendacion por primera vez
def recomendacion(dedopromedio, terminado, recomendacion, original):
    print('Generaremos las recomendaciones usando los resultados obtenidos de tus canciones y Frecuencia cardiaca')
    np.savetxt("./terminado.csv", terminado, delimiter= "")
    recomendacion.to_csv("./recomendacion.csv", index = False)
    
    reformado = np.array([], dtype = float)
    for lectura in terminado:
        reformado = np.append(reformado, abs(lectura - dedopromedio))
    cercanocero = reformado.min()
    cluster = 0
    for indice in range(len(reformado)):
        if reformado[indice]== cercanocero:
            cluster= indice
    recomendacion = recomendacion[recomendacion['Cluster12'] == cluster]
    recomendacion = recomendacion.rename(columns = {'id':'track.id'})
    href = pd.merge(original, recomendacion, on='track.id', how='left')
    href.dropna(inplace = True)
    external = href['track.external_urls.spotify']
    return external

# %%
#Creamos nuevas recomendaciones usamos modelos ya creados
def nuevaRec(dedopromedio):
    print('Generaremos las recomendaciones usando los resultados obtenidos de tus canciones y Frecuencia cardiaca')
    terminado = genfromtxt("./terminado.csv", delimiter=',')
    recomendacion_csv = pd.read_csv("./recomendacion.csv")
    original_csv = pd.read_csv('./SpotifyApi.csv')
    
    recomendacion = pd.DataFrame(recomendacion_csv)
    original= pd.DataFrame(original_csv)
    
    reformado = np.array([], dtype = float)
    for lectura in terminado:
        reformado = np.append(reformado, abs(lectura - dedopromedio))

    cercanocero = reformado.min()
    cluster = 0
    for indice in range(len(reformado)):
        if reformado[indice]== cercanocero:
            cluster= indice
    recomendacion = recomendacion[recomendacion['Cluster12'] == cluster]
    recomendacion = recomendacion.rename(columns = {'id':'track.id'})

    href = pd.merge(original, recomendacion, on='track.id', how='left')
    href.dropna(inplace = True)

    external = href['track.external_urls.spotify']
    return external

# %%
def presentacion(external):
    driver = webdriver.Chrome()
    driver.get('https://open.spotify.com')
    driver.find_element_by_xpath("/html/body/div[1]/div/div[5]/div[1]/nav/div[2]/div/p[2]/button").click()
    time.sleep(2)
    driver.find_element_by_xpath("/html/body/div[1]/div[2]/div/div[2]/div/a").click()
    time.sleep(1)

    usr='shiroiusagi4486@gmail.com'
    pwd='wero5039'

    username_box = driver.find_element_by_id('email') 
    username_box.send_keys(usr) 
    print ("Email Id entered") 
    time.sleep(1) 

    password_box = driver.find_element_by_id('pass') 
    password_box.send_keys(pwd) 
    print ("Password entered") 

    login_box = driver.find_element_by_id('loginbutton') 
    login_box.click()
    print ("Done") 

    aleatorio = random.sample(external, k=10)

    for url in aleatorio
        driver.get(url)
        time.sleep(120)

    driver.quit()

# %%
# Out:
# Es la primera vez que nos visitas?
# teclea S para si, n para No s
# Bienvenido a EarBeat, para generar las playlist que sean acordes a tu frecuencia cardiaca, te pediremos que introduzcas algunos datos y procesaremos otros, esto puede tomar algun tiempo, por favor se paciente
# Estaremos avisandote de todo el proceso y gracias por utilizarnos
# Hola, introduce el link de tu enlace de perfil de spotify, puedes introducir cualquier otra cosa para salir https://open.spotify.com/user/12101725182?si=ZXZ11ye_SI-N93A9ZgJpRg
# Hola, introduce el link de tu enlace de perfil de spotify, puedes introducir cualquier otra cosa para salir
# Obteniendo datos, no desesperes
# Scrap de paginas terminado, gracias por tus datos
# Hola nos estamos conectando a la API de Spotify
# Espero no tardar con la obtencion de canciones de la lista que me has mandado, asi que no desesperes
# He terminado con obtención de canciones
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\program files\python37\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Comenzando con la obtencion de caracteristicas de cada canción de tus listas
# Elemento: 1  de  1745
# Elemento: 2  de  1745
# Elemento: 3  de  1745
# Elemento: 4  de  1745
# Elemento: 5  de  1745
# Elemento: 6  de  1745
# Elemento: 7  de  1745
# Elemento: 8  de  1745
# Elemento: 9  de  1745
# Elemento: 10  de  1745
# Elemento: 11  de  1745
# Elemento: 12  de  1745
# Elemento: 13  de  1745
# Elemento: 14  de  1745
# Elemento: 15  de  1745
# Elemento: 16  de  1745
# Elemento: 17  de  1745
# Elemento: 18  de  1745
# Elemento: 19  de  1745
# Elemento: 20  de  1745
# Elemento: 21  de  1745
# Elemento: 22  de  1745
# Elemento: 23  de  1745
# Elemento: 24  de  1745
# Elemento: 25  de  1745
# Elemento: 26  de  1745
# Elemento: 27  de  1745
# Elemento: 28  de  1745
# Elemento: 29  de  1745
# Elemento: 30  de  1745
# Elemento: 31  de  1745
# Elemento: 32  de  1745
# Elemento: 33  de  1745
# Elemento: 34  de  1745
# Elemento: 35  de  1745
# Elemento: 36  de  1745
# Elemento: 37  de  1745
# Elemento: 38  de  1745
# Elemento: 39  de  1745
# Elemento: 40  de  1745
# Elemento: 41  de  1745
# Elemento: 42  de  1745
# Elemento: 43  de  1745
# Elemento: 44  de  1745
# Elemento: 45  de  1745
# Elemento: 46  de  1745
# Elemento: 47  de  1745
# Elemento: 48  de  1745
# Elemento: 49  de  1745
# Elemento: 50  de  1745
# Elemento: 51  de  1745
# Elemento: 52  de  1745
# Elemento: 53  de  1745
# Elemento: 54  de  1745
# Elemento: 55  de  1745
# Elemento: 56  de  1745
# Elemento: 57  de  1745
# Elemento: 58  de  1745
# Elemento: 59  de  1745
# Elemento: 60  de  1745
# Elemento: 61  de  1745
# Elemento: 62  de  1745
# Elemento: 63  de  1745
# Elemento: 64  de  1745
# Elemento: 65  de  1745
# Elemento: 66  de  1745
# Elemento: 67  de  1745
# Elemento: 68  de  1745
# Elemento: 69  de  1745
# Elemento: 70  de  1745
# Elemento: 71  de  1745
# Elemento: 72  de  1745
# Elemento: 73  de  1745
# Elemento: 74  de  1745
# Elemento: 75  de  1745
# Elemento: 76  de  1745
# Elemento: 77  de  1745
# Elemento: 78  de  1745
# Elemento: 79  de  1745
# Elemento: 80  de  1745
# Elemento: 81  de  1745
# Elemento: 82  de  1745
# Elemento: 83  de  1745
# Elemento: 84  de  1745
# Elemento: 85  de  1745
# Elemento: 86  de  1745
# Elemento: 87  de  1745
# Elemento: 88  de  1745
# Elemento: 89  de  1745
# Elemento: 90  de  1745
# Elemento: 91  de  1745
# Elemento: 92  de  1745
# Elemento: 93  de  1745
# Elemento: 94  de  1745
# Elemento: 95  de  1745
# Elemento: 96  de  1745
# Elemento: 97  de  1745
# Elemento: 98  de  1745
# Elemento: 99  de  1745
# Elemento: 100  de  1745
# Elemento: 101  de  1745
# Elemento: 102  de  1745
# Elemento: 103  de  1745
# Elemento: 104  de  1745
# Elemento: 105  de  1745
# Elemento: 106  de  1745
# Elemento: 107  de  1745
# Elemento: 108  de  1745
# Elemento: 109  de  1745
# Elemento: 110  de  1745
# Elemento: 111  de  1745
# Elemento: 112  de  1745
# Elemento: 113  de  1745
# Elemento: 114  de  1745
# Elemento: 115  de  1745
# Elemento: 116  de  1745
# Elemento: 117  de  1745
# Elemento: 118  de  1745
# Elemento: 119  de  1745
# Elemento: 120  de  1745
# Elemento: 121  de  1745
# Elemento: 122  de  1745
# Elemento: 123  de  1745
# Elemento: 124  de  1745
# Elemento: 125  de  1745
# Elemento: 126  de  1745
# Elemento: 127  de  1745
# Elemento: 128  de  1745
# Elemento: 129  de  1745
# Elemento: 130  de  1745
# Elemento: 131  de  1745
# Elemento: 132  de  1745
# Elemento: 133  de  1745
# Elemento: 134  de  1745
# Elemento: 135  de  1745
# Elemento: 136  de  1745
# Elemento: 137  de  1745
# Elemento: 138  de  1745
# Elemento: 139  de  1745
# Elemento: 140  de  1745
# Elemento: 141  de  1745
# Elemento: 142  de  1745
# Elemento: 143  de  1745
# Elemento: 144  de  1745
# Elemento: 145  de  1745
# Elemento: 146  de  1745
# Elemento: 147  de  1745
# Elemento: 148  de  1745
# Elemento: 149  de  1745
# Elemento: 150  de  1745
# Elemento: 151  de  1745
# Elemento: 152  de  1745
# Elemento: 153  de  1745
# Elemento: 154  de  1745
# Elemento: 155  de  1745
# Elemento: 156  de  1745
# Elemento: 157  de  1745
# Elemento: 158  de  1745
# Elemento: 159  de  1745
# Elemento: 160  de  1745
# Elemento: 161  de  1745
# Elemento: 162  de  1745
# Elemento: 163  de  1745
# Elemento: 164  de  1745
# Elemento: 165  de  1745
# Elemento: 166  de  1745
# Elemento: 167  de  1745
# Elemento: 168  de  1745
# Elemento: 169  de  1745
# Elemento: 170  de  1745
# Elemento: 171  de  1745
# Elemento: 172  de  1745
# Elemento: 173  de  1745
# Elemento: 174  de  1745
# Elemento: 175  de  1745
# Elemento: 176  de  1745
# Elemento: 177  de  1745
# Elemento: 178  de  1745
# Elemento: 179  de  1745
# Elemento: 180  de  1745
# Elemento: 181  de  1745
# Elemento: 182  de  1745
# Elemento: 183  de  1745
# Elemento: 184  de  1745
# Elemento: 185  de  1745
# Elemento: 186  de  1745
# Elemento: 187  de  1745
# Elemento: 188  de  1745
# Elemento: 189  de  1745
# Elemento: 190  de  1745
# Elemento: 191  de  1745
# Elemento: 192  de  1745
# Elemento: 193  de  1745
# Elemento: 194  de  1745
# Elemento: 195  de  1745
# Elemento: 196  de  1745
# Elemento: 197  de  1745
# Elemento: 198  de  1745
# Elemento: 199  de  1745
# Elemento: 200  de  1745
# Elemento: 201  de  1745
# Elemento: 202  de  1745
# Elemento: 203  de  1745
# Elemento: 204  de  1745
# Elemento: 205  de  1745
# Elemento: 206  de  1745
# Elemento: 207  de  1745
# Elemento: 208  de  1745
# Elemento: 209  de  1745
# Elemento: 210  de  1745
# Elemento: 211  de  1745
# Elemento: 212  de  1745
# Elemento: 213  de  1745
# Elemento: 214  de  1745
# Elemento: 215  de  1745
# Elemento: 216  de  1745
# Elemento: 217  de  1745
# Elemento: 218  de  1745
# Elemento: 219  de  1745
# Elemento: 220  de  1745
# Elemento: 221  de  1745
# Elemento: 222  de  1745
# Elemento: 223  de  1745
# Elemento: 224  de  1745
# Elemento: 225  de  1745
# Elemento: 226  de  1745
# Elemento: 227  de  1745
# Elemento: 228  de  1745
# Elemento: 229  de  1745
# Elemento: 230  de  1745
# Elemento: 231  de  1745
# Elemento: 232  de  1745
# Elemento: 233  de  1745
# Elemento: 234  de  1745
# Elemento: 235  de  1745
# Elemento: 236  de  1745
# Elemento: 237  de  1745
# Elemento: 238  de  1745
# Elemento: 239  de  1745
# Elemento: 240  de  1745
# Elemento: 241  de  1745
# Elemento: 242  de  1745
# Elemento: 243  de  1745
# Elemento: 244  de  1745
# Elemento: 245  de  1745
# Elemento: 246  de  1745
# Elemento: 247  de  1745
# Elemento: 248  de  1745
# Elemento: 249  de  1745
# Elemento: 250  de  1745
# Elemento: 251  de  1745
# Elemento: 252  de  1745
# Elemento: 253  de  1745
# Elemento: 254  de  1745
# Elemento: 255  de  1745
# Elemento: 256  de  1745
# Elemento: 257  de  1745
# Elemento: 258  de  1745
# Elemento: 259  de  1745
# Elemento: 260  de  1745
# Elemento: 261  de  1745
# Elemento: 262  de  1745
# Elemento: 263  de  1745
# Elemento: 264  de  1745
# Elemento: 265  de  1745
# Elemento: 266  de  1745
# Elemento: 267  de  1745
# Elemento: 268  de  1745
# Elemento: 269  de  1745
# Elemento: 270  de  1745
# Elemento: 271  de  1745
# Elemento: 272  de  1745
# Elemento: 273  de  1745
# Elemento: 274  de  1745
# Elemento: 275  de  1745
# Elemento: 276  de  1745
# Elemento: 277  de  1745
# Elemento: 278  de  1745
# Elemento: 279  de  1745
# Elemento: 280  de  1745
# Elemento: 281  de  1745
# Elemento: 282  de  1745
# Elemento: 283  de  1745
# Elemento: 284  de  1745
# Elemento: 285  de  1745
# Elemento: 286  de  1745
# Elemento: 287  de  1745
# Elemento: 288  de  1745
# Elemento: 289  de  1745
# Elemento: 290  de  1745
# Elemento: 291  de  1745
# Elemento: 292  de  1745
# Elemento: 293  de  1745
# Elemento: 294  de  1745
# Elemento: 295  de  1745
# Elemento: 296  de  1745
# Elemento: 297  de  1745
# Elemento: 298  de  1745
# Elemento: 299  de  1745
# Elemento: 300  de  1745
# Elemento: 301  de  1745
# Elemento: 302  de  1745
# Elemento: 303  de  1745
# Elemento: 304  de  1745
# Elemento: 305  de  1745
# Elemento: 306  de  1745
# Elemento: 307  de  1745
# Elemento: 308  de  1745
# Elemento: 309  de  1745
# Elemento: 310  de  1745
# Elemento: 311  de  1745
# Elemento: 312  de  1745
# Elemento: 313  de  1745
# Elemento: 314  de  1745
# Elemento: 315  de  1745
# Elemento: 316  de  1745
# Elemento: 317  de  1745
# Elemento: 318  de  1745
# Elemento: 319  de  1745
# Elemento: 320  de  1745
# Elemento: 321  de  1745
# Elemento: 322  de  1745
# Elemento: 323  de  1745
# Elemento: 324  de  1745
# Elemento: 325  de  1745
# Elemento: 326  de  1745
# Elemento: 327  de  1745
# Elemento: 328  de  1745
# Elemento: 329  de  1745
# Elemento: 330  de  1745
# Elemento: 331  de  1745
# Elemento: 332  de  1745
# Elemento: 333  de  1745
# Elemento: 334  de  1745
# Elemento: 335  de  1745
# Elemento: 336  de  1745
# Elemento: 337  de  1745
# Elemento: 338  de  1745
# Elemento: 339  de  1745
# Elemento: 340  de  1745
# Elemento: 341  de  1745
# Elemento: 342  de  1745
# Elemento: 343  de  1745
# Elemento: 344  de  1745
# Elemento: 345  de  1745
# Elemento: 346  de  1745
# Elemento: 347  de  1745
# Elemento: 348  de  1745
# Elemento: 349  de  1745
# Elemento: 350  de  1745
# Elemento: 351  de  1745
# Elemento: 352  de  1745
# Elemento: 353  de  1745
# Elemento: 354  de  1745
# Elemento: 355  de  1745
# Elemento: 356  de  1745
# Elemento: 357  de  1745
# Elemento: 358  de  1745
# Elemento: 359  de  1745
# Elemento: 360  de  1745
# Elemento: 361  de  1745
# Elemento: 362  de  1745
# Elemento: 363  de  1745
# Elemento: 364  de  1745
# Elemento: 365  de  1745
# Elemento: 366  de  1745
# Elemento: 367  de  1745
# Elemento: 368  de  1745
# Elemento: 369  de  1745
# Elemento: 370  de  1745
# Elemento: 371  de  1745
# Elemento: 372  de  1745
# Elemento: 373  de  1745
# Elemento: 374  de  1745
# Elemento: 375  de  1745
# Elemento: 376  de  1745
# Elemento: 377  de  1745
# Elemento: 378  de  1745
# Elemento: 379  de  1745
# Elemento: 380  de  1745
# Elemento: 381  de  1745
# Elemento: 382  de  1745
# Elemento: 383  de  1745
# Elemento: 384  de  1745
# Elemento: 385  de  1745
# Elemento: 386  de  1745
# Elemento: 387  de  1745
# Elemento: 388  de  1745
# Elemento: 389  de  1745
# Elemento: 390  de  1745
# Elemento: 391  de  1745
# Elemento: 392  de  1745
# Elemento: 393  de  1745
# Elemento: 394  de  1745
# Elemento: 395  de  1745
# Elemento: 396  de  1745
# Elemento: 397  de  1745
# Elemento: 398  de  1745
# Elemento: 399  de  1745
# Elemento: 400  de  1745
# Elemento: 401  de  1745
# Elemento: 402  de  1745
# Elemento: 403  de  1745
# Elemento: 404  de  1745
# Elemento: 405  de  1745
# Elemento: 406  de  1745
# Elemento: 407  de  1745
# Elemento: 408  de  1745
# Elemento: 409  de  1745
# Elemento: 410  de  1745
# Elemento: 411  de  1745
# Elemento: 412  de  1745
# Elemento: 413  de  1745
# Elemento: 414  de  1745
# Elemento: 415  de  1745
# Elemento: 416  de  1745
# Elemento: 417  de  1745
# Elemento: 418  de  1745
# Elemento: 419  de  1745
# Elemento: 420  de  1745
# Elemento: 421  de  1745
# Elemento: 422  de  1745
# Elemento: 423  de  1745
# Elemento: 424  de  1745
# Elemento: 425  de  1745
# Elemento: 426  de  1745
# Elemento: 427  de  1745
# Elemento: 428  de  1745
# Elemento: 429  de  1745
# Elemento: 430  de  1745
# Elemento: 431  de  1745
# Elemento: 432  de  1745
# Elemento: 433  de  1745
# Elemento: 434  de  1745
# Elemento: 435  de  1745
# Elemento: 436  de  1745
# Elemento: 437  de  1745
# Elemento: 438  de  1745
# Elemento: 439  de  1745
# Elemento: 440  de  1745
# Elemento: 441  de  1745
# Elemento: 442  de  1745
# Elemento: 443  de  1745
# Elemento: 444  de  1745
# Elemento: 445  de  1745
# Elemento: 446  de  1745
# Elemento: 447  de  1745
# Elemento: 448  de  1745
# Elemento: 449  de  1745
# Elemento: 450  de  1745
# Elemento: 451  de  1745
# Elemento: 452  de  1745
# Elemento: 453  de  1745
# Elemento: 454  de  1745
# Elemento: 455  de  1745
# Elemento: 456  de  1745
# Elemento: 457  de  1745
# Elemento: 458  de  1745
# Elemento: 459  de  1745
# Elemento: 460  de  1745
# Elemento: 461  de  1745
# Elemento: 462  de  1745
# Elemento: 463  de  1745
# Elemento: 464  de  1745
# Elemento: 465  de  1745
# Elemento: 466  de  1745
# Elemento: 467  de  1745
# Elemento: 468  de  1745
# Elemento: 469  de  1745
# Elemento: 470  de  1745
# Elemento: 471  de  1745
# Elemento: 472  de  1745
# Elemento: 473  de  1745
# Elemento: 474  de  1745
# Elemento: 475  de  1745
# Elemento: 476  de  1745
# Elemento: 477  de  1745
# Elemento: 478  de  1745
# Elemento: 479  de  1745
# Elemento: 480  de  1745
# Elemento: 481  de  1745
# Elemento: 482  de  1745
# Elemento: 483  de  1745
# Elemento: 484  de  1745
# Elemento: 485  de  1745
# Elemento: 486  de  1745
# Elemento: 487  de  1745
# Elemento: 488  de  1745
# Elemento: 489  de  1745
# Elemento: 490  de  1745
# Elemento: 491  de  1745
# Elemento: 492  de  1745
# Elemento: 493  de  1745
# Elemento: 494  de  1745
# Elemento: 495  de  1745
# Elemento: 496  de  1745
# Elemento: 497  de  1745
# Elemento: 498  de  1745
# Elemento: 499  de  1745
# Elemento: 500  de  1745
# Elemento: 501  de  1745
# Elemento: 502  de  1745
# Elemento: 503  de  1745
# Elemento: 504  de  1745
# Elemento: 505  de  1745
# Elemento: 506  de  1745
# Elemento: 507  de  1745
# Elemento: 508  de  1745
# Elemento: 509  de  1745
# Elemento: 510  de  1745
# Elemento: 511  de  1745
# Elemento: 512  de  1745
# Elemento: 513  de  1745
# Elemento: 514  de  1745
# Elemento: 515  de  1745
# Elemento: 516  de  1745
# Elemento: 517  de  1745
# Elemento: 518  de  1745
# Elemento: 519  de  1745
# Elemento: 520  de  1745
# Elemento: 521  de  1745
# Elemento: 522  de  1745
# Elemento: 523  de  1745
# Elemento: 524  de  1745
# Elemento: 525  de  1745
# Elemento: 526  de  1745
# Elemento: 527  de  1745
# Elemento: 528  de  1745
# Elemento: 529  de  1745
# Elemento: 530  de  1745
# Elemento: 531  de  1745
# Elemento: 532  de  1745
# Elemento: 533  de  1745
# Elemento: 534  de  1745
# Elemento: 535  de  1745
# Elemento: 536  de  1745
# Elemento: 537  de  1745
# Elemento: 538  de  1745
# Elemento: 539  de  1745
# Elemento: 540  de  1745
# Elemento: 541  de  1745
# Elemento: 542  de  1745
# Elemento: 543  de  1745
# Elemento: 544  de  1745
# Elemento: 545  de  1745
# Elemento: 546  de  1745
# Elemento: 547  de  1745
# Elemento: 548  de  1745
# Elemento: 549  de  1745
# Elemento: 550  de  1745
# Elemento: 551  de  1745
# Elemento: 552  de  1745
# Elemento: 553  de  1745
# Elemento: 554  de  1745
# Elemento: 555  de  1745
# Elemento: 556  de  1745
# Elemento: 557  de  1745
# Elemento: 558  de  1745
# Elemento: 559  de  1745
# Elemento: 560  de  1745
# Elemento: 561  de  1745
# Elemento: 562  de  1745
# Elemento: 563  de  1745
# Elemento: 564  de  1745
# Elemento: 565  de  1745
# Elemento: 566  de  1745
# Elemento: 567  de  1745
# Elemento: 568  de  1745
# Elemento: 569  de  1745
# Elemento: 570  de  1745
# Elemento: 571  de  1745
# Elemento: 572  de  1745
# Elemento: 573  de  1745
# Elemento: 574  de  1745
# Elemento: 575  de  1745
# Elemento: 576  de  1745
# Elemento: 577  de  1745
# Elemento: 578  de  1745
# Elemento: 579  de  1745
# Elemento: 580  de  1745
# Elemento: 581  de  1745
# Elemento: 582  de  1745
# Elemento: 583  de  1745
# Elemento: 584  de  1745
# Elemento: 585  de  1745
# Elemento: 586  de  1745
# Elemento: 587  de  1745
# Elemento: 588  de  1745
# Elemento: 589  de  1745
# Elemento: 590  de  1745
# Elemento: 591  de  1745
# Elemento: 592  de  1745
# Elemento: 593  de  1745
# Elemento: 594  de  1745
# Elemento: 595  de  1745
# Elemento: 596  de  1745
# Elemento: 597  de  1745
# Elemento: 598  de  1745
# Elemento: 599  de  1745
# Elemento: 600  de  1745
# Elemento: 601  de  1745
# Elemento: 602  de  1745
# Elemento: 603  de  1745
# Elemento: 604  de  1745
# Elemento: 605  de  1745
# Elemento: 606  de  1745
# Elemento: 607  de  1745
# Elemento: 608  de  1745
# Elemento: 609  de  1745
# Elemento: 610  de  1745
# Elemento: 611  de  1745
# Elemento: 612  de  1745
# Elemento: 613  de  1745
# Elemento: 614  de  1745
# Elemento: 615  de  1745
# Elemento: 616  de  1745
# Elemento: 617  de  1745
# Elemento: 618  de  1745
# Elemento: 619  de  1745
# Elemento: 620  de  1745
# Elemento: 621  de  1745
# Elemento: 622  de  1745
# Elemento: 623  de  1745
# Elemento: 624  de  1745
# Elemento: 625  de  1745
# Elemento: 626  de  1745
# Elemento: 627  de  1745
# Elemento: 628  de  1745
# Elemento: 629  de  1745
# Elemento: 630  de  1745
# Elemento: 631  de  1745
# Elemento: 632  de  1745
# Elemento: 633  de  1745
# Elemento: 634  de  1745
# Elemento: 635  de  1745
# Elemento: 636  de  1745
# Elemento: 637  de  1745
# Elemento: 638  de  1745
# Elemento: 639  de  1745
# Elemento: 640  de  1745
# Elemento: 641  de  1745
# Elemento: 642  de  1745
# Elemento: 643  de  1745
# Elemento: 644  de  1745
# Elemento: 645  de  1745
# Elemento: 646  de  1745
# Elemento: 647  de  1745
# Elemento: 648  de  1745
# Elemento: 649  de  1745
# Elemento: 650  de  1745
# Elemento: 651  de  1745
# Elemento: 652  de  1745
# Elemento: 653  de  1745
# Elemento: 654  de  1745
# Elemento: 655  de  1745
# Elemento: 656  de  1745
# Elemento: 657  de  1745
# Elemento: 658  de  1745
# Elemento: 659  de  1745
# Elemento: 660  de  1745
# Elemento: 661  de  1745
# Elemento: 662  de  1745
# Elemento: 663  de  1745
# Elemento: 664  de  1745
# Elemento: 665  de  1745
# Elemento: 666  de  1745
# Elemento: 667  de  1745
# Elemento: 668  de  1745
# Elemento: 669  de  1745
# Elemento: 670  de  1745
# Elemento: 671  de  1745
# Elemento: 672  de  1745
# Elemento: 673  de  1745
# Elemento: 674  de  1745
# Elemento: 675  de  1745
# Elemento: 676  de  1745
# Elemento: 677  de  1745
# Elemento: 678  de  1745
# Elemento: 679  de  1745
# Elemento: 680  de  1745
# Elemento: 681  de  1745
# Elemento: 682  de  1745
# Elemento: 683  de  1745
# Elemento: 684  de  1745
# Elemento: 685  de  1745
# Elemento: 686  de  1745
# Elemento: 687  de  1745
# Elemento: 688  de  1745
# Elemento: 689  de  1745
# Elemento: 690  de  1745
# Elemento: 691  de  1745
# Elemento: 692  de  1745
# Elemento: 693  de  1745
# Elemento: 694  de  1745
# Elemento: 695  de  1745
# Elemento: 696  de  1745
# Elemento: 697  de  1745
# Elemento: 698  de  1745
# Elemento: 699  de  1745
# Elemento: 700  de  1745
# Elemento: 701  de  1745
# Elemento: 702  de  1745
# Elemento: 703  de  1745
# Elemento: 704  de  1745
# Elemento: 705  de  1745
# Elemento: 706  de  1745
# Elemento: 707  de  1745
# Elemento: 708  de  1745
# Elemento: 709  de  1745
# Elemento: 710  de  1745
# Elemento: 711  de  1745
# Elemento: 712  de  1745
# Elemento: 713  de  1745
# Elemento: 714  de  1745
# Elemento: 715  de  1745
# Elemento: 716  de  1745
# Elemento: 717  de  1745
# Elemento: 718  de  1745
# Elemento: 719  de  1745
# Elemento: 720  de  1745
# Elemento: 721  de  1745
# Elemento: 722  de  1745
# Elemento: 723  de  1745
# Elemento: 724  de  1745
# Elemento: 725  de  1745
# Elemento: 726  de  1745
# Elemento: 727  de  1745
# Elemento: 728  de  1745
# Elemento: 729  de  1745
# Elemento: 730  de  1745
# Elemento: 731  de  1745
# Elemento: 732  de  1745
# Elemento: 733  de  1745
# Elemento: 734  de  1745
# Elemento: 735  de  1745
# Elemento: 736  de  1745
# Elemento: 737  de  1745
# Elemento: 738  de  1745
# Elemento: 739  de  1745
# Elemento: 740  de  1745
# Elemento: 741  de  1745
# Elemento: 742  de  1745
# Elemento: 743  de  1745
# Elemento: 744  de  1745
# Elemento: 745  de  1745
# Elemento: 746  de  1745
# Elemento: 747  de  1745
# Elemento: 748  de  1745
# Elemento: 749  de  1745
# Elemento: 750  de  1745
# Elemento: 751  de  1745
# Elemento: 752  de  1745
# Elemento: 753  de  1745
# Elemento: 754  de  1745
# Elemento: 755  de  1745
# Elemento: 756  de  1745
# Elemento: 757  de  1745
# Elemento: 758  de  1745
# Elemento: 759  de  1745
# Elemento: 760  de  1745
# Elemento: 761  de  1745
# Elemento: 762  de  1745
# Elemento: 763  de  1745
# Elemento: 764  de  1745
# Elemento: 765  de  1745
# Elemento: 766  de  1745
# Elemento: 767  de  1745
# Elemento: 768  de  1745
# Elemento: 769  de  1745
# Elemento: 770  de  1745
# Elemento: 771  de  1745
# Elemento: 772  de  1745
# Elemento: 773  de  1745
# Elemento: 774  de  1745
# Elemento: 775  de  1745
# Elemento: 776  de  1745
# Elemento: 777  de  1745
# Elemento: 778  de  1745
# Elemento: 779  de  1745
# Elemento: 780  de  1745
# Elemento: 781  de  1745
# Elemento: 782  de  1745
# Elemento: 783  de  1745
# Elemento: 784  de  1745
# Elemento: 785  de  1745
# Elemento: 786  de  1745
# Elemento: 787  de  1745
# Elemento: 788  de  1745
# Elemento: 789  de  1745
# Elemento: 790  de  1745
# Elemento: 791  de  1745
# Elemento: 792  de  1745
# Elemento: 793  de  1745
# Elemento: 794  de  1745
# Elemento: 795  de  1745
# Elemento: 796  de  1745
# Elemento: 797  de  1745
# Elemento: 798  de  1745
# Elemento: 799  de  1745
# Elemento: 800  de  1745
# Elemento: 801  de  1745
# Elemento: 802  de  1745
# Elemento: 803  de  1745
# Elemento: 804  de  1745
# Elemento: 805  de  1745
# Elemento: 806  de  1745
# Elemento: 807  de  1745
# Elemento: 808  de  1745
# Elemento: 809  de  1745
# Elemento: 810  de  1745
# Elemento: 811  de  1745
# Elemento: 812  de  1745
# Elemento: 813  de  1745
# Elemento: 814  de  1745
# Elemento: 815  de  1745
# Elemento: 816  de  1745
# Elemento: 817  de  1745
# Elemento: 818  de  1745
# Elemento: 819  de  1745
# Elemento: 820  de  1745
# Elemento: 821  de  1745
# Elemento: 822  de  1745
# Elemento: 823  de  1745
# Elemento: 824  de  1745
# Elemento: 825  de  1745
# Elemento: 826  de  1745
# Elemento: 827  de  1745
# Elemento: 828  de  1745
# Elemento: 829  de  1745
# Elemento: 830  de  1745
# Elemento: 831  de  1745
# Elemento: 832  de  1745
# Elemento: 833  de  1745
# Elemento: 834  de  1745
# Elemento: 835  de  1745
# Elemento: 836  de  1745
# Elemento: 837  de  1745
# Elemento: 838  de  1745
# Elemento: 839  de  1745
# Elemento: 840  de  1745
# Elemento: 841  de  1745
# Elemento: 842  de  1745
# Elemento: 843  de  1745
# Elemento: 844  de  1745
# Elemento: 845  de  1745
# Elemento: 846  de  1745
# Elemento: 847  de  1745
# Elemento: 848  de  1745
# Elemento: 849  de  1745
# Elemento: 850  de  1745
# Elemento: 851  de  1745
# Elemento: 852  de  1745
# Elemento: 853  de  1745
# Elemento: 854  de  1745
# Elemento: 855  de  1745
# Elemento: 856  de  1745
# Elemento: 857  de  1745
# Elemento: 858  de  1745
# Elemento: 859  de  1745
# Elemento: 860  de  1745
# Elemento: 861  de  1745
# Elemento: 862  de  1745
# Elemento: 863  de  1745
# Elemento: 864  de  1745
# Elemento: 865  de  1745
# Elemento: 866  de  1745
# Elemento: 867  de  1745
# Elemento: 868  de  1745
# Elemento: 869  de  1745
# Elemento: 870  de  1745
# Elemento: 871  de  1745
# Elemento: 872  de  1745
# Elemento: 873  de  1745
# Elemento: 874  de  1745
# Elemento: 875  de  1745
# Elemento: 876  de  1745
# Elemento: 877  de  1745
# Elemento: 878  de  1745
# Elemento: 879  de  1745
# Elemento: 880  de  1745
# Elemento: 881  de  1745
# Elemento: 882  de  1745
# Elemento: 883  de  1745
# Elemento: 884  de  1745
# Elemento: 885  de  1745
# Elemento: 886  de  1745
# Elemento: 887  de  1745
# Elemento: 888  de  1745
# Elemento: 889  de  1745
# Elemento: 890  de  1745
# Elemento: 891  de  1745
# Elemento: 892  de  1745
# Elemento: 893  de  1745
# Elemento: 894  de  1745
# Elemento: 895  de  1745
# Elemento: 896  de  1745
# Elemento: 897  de  1745
# Elemento: 898  de  1745
# Elemento: 899  de  1745
# Elemento: 900  de  1745
# Elemento: 901  de  1745
# Elemento: 902  de  1745
# Elemento: 903  de  1745
# Elemento: 904  de  1745
# Elemento: 905  de  1745
# Elemento: 906  de  1745
# Elemento: 907  de  1745
# Elemento: 908  de  1745
# Elemento: 909  de  1745
# Elemento: 910  de  1745
# Elemento: 911  de  1745
# Elemento: 912  de  1745
# Elemento: 913  de  1745
# Elemento: 914  de  1745
# Elemento: 915  de  1745
# Elemento: 916  de  1745
# Elemento: 917  de  1745
# Elemento: 918  de  1745
# Elemento: 919  de  1745
# Elemento: 920  de  1745
# Elemento: 921  de  1745
# Elemento: 922  de  1745
# Elemento: 923  de  1745
# Elemento: 924  de  1745
# Elemento: 925  de  1745
# Elemento: 926  de  1745
# Elemento: 927  de  1745
# Elemento: 928  de  1745
# Elemento: 929  de  1745
# Elemento: 930  de  1745
# Elemento: 931  de  1745
# Elemento: 932  de  1745
# Elemento: 933  de  1745
# Elemento: 934  de  1745
# Elemento: 935  de  1745
# Elemento: 936  de  1745
# Elemento: 937  de  1745
# Elemento: 938  de  1745
# Elemento: 939  de  1745
# Elemento: 940  de  1745
# Elemento: 941  de  1745
# Elemento: 942  de  1745
# Elemento: 943  de  1745
# Elemento: 944  de  1745
# Elemento: 945  de  1745
# Elemento: 946  de  1745
# Elemento: 947  de  1745
# Elemento: 948  de  1745
# Elemento: 949  de  1745
# Elemento: 950  de  1745
# Elemento: 951  de  1745
# Elemento: 952  de  1745
# Elemento: 953  de  1745
# Elemento: 954  de  1745
# Elemento: 955  de  1745
# Elemento: 956  de  1745
# Elemento: 957  de  1745
# Elemento: 958  de  1745
# Elemento: 959  de  1745
# Elemento: 960  de  1745
# Elemento: 961  de  1745
# Elemento: 962  de  1745
# Elemento: 963  de  1745
# Elemento: 964  de  1745
# Elemento: 965  de  1745
# Elemento: 966  de  1745
# Elemento: 967  de  1745
# Elemento: 968  de  1745
# Elemento: 969  de  1745
# Elemento: 970  de  1745
# Elemento: 971  de  1745
# Elemento: 972  de  1745
# Elemento: 973  de  1745
# Elemento: 974  de  1745
# Elemento: 975  de  1745
# Elemento: 976  de  1745
# Elemento: 977  de  1745
# Elemento: 978  de  1745
# Elemento: 979  de  1745
# Elemento: 980  de  1745
# Elemento: 981  de  1745
# Elemento: 982  de  1745
# Elemento: 983  de  1745
# Elemento: 984  de  1745
# Elemento: 985  de  1745
# Elemento: 986  de  1745
# Elemento: 987  de  1745
# Elemento: 988  de  1745
# Elemento: 989  de  1745
# Elemento: 990  de  1745
# Elemento: 991  de  1745
# Elemento: 992  de  1745
# Elemento: 993  de  1745
# Elemento: 994  de  1745
# Elemento: 995  de  1745
# Elemento: 996  de  1745
# Elemento: 997  de  1745
# Elemento: 998  de  1745
# Elemento: 999  de  1745
# Elemento: 1000  de  1745
# Elemento: 1001  de  1745
# Elemento: 1002  de  1745
# Elemento: 1003  de  1745
# Elemento: 1004  de  1745
# Elemento: 1005  de  1745
# Elemento: 1006  de  1745
# Elemento: 1007  de  1745
# Elemento: 1008  de  1745
# Elemento: 1009  de  1745
# Elemento: 1010  de  1745
# Elemento: 1011  de  1745
# Elemento: 1012  de  1745
# Elemento: 1013  de  1745
# Elemento: 1014  de  1745
# Elemento: 1015  de  1745
# Elemento: 1016  de  1745
# Elemento: 1017  de  1745
# Elemento: 1018  de  1745
# Elemento: 1019  de  1745
# Elemento: 1020  de  1745
# Elemento: 1021  de  1745
# Elemento: 1022  de  1745
# Elemento: 1023  de  1745
# Elemento: 1024  de  1745
# Elemento: 1025  de  1745
# Elemento: 1026  de  1745
# Elemento: 1027  de  1745
# Elemento: 1028  de  1745
# Elemento: 1029  de  1745
# Elemento: 1030  de  1745
# Elemento: 1031  de  1745
# Elemento: 1032  de  1745
# Elemento: 1033  de  1745
# Elemento: 1034  de  1745
# Elemento: 1035  de  1745
# Elemento: 1036  de  1745
# Elemento: 1037  de  1745
# Elemento: 1038  de  1745
# Elemento: 1039  de  1745
# Elemento: 1040  de  1745
# Elemento: 1041  de  1745
# Elemento: 1042  de  1745
# Elemento: 1043  de  1745
# Elemento: 1044  de  1745
# Elemento: 1045  de  1745
# Elemento: 1046  de  1745
# Elemento: 1047  de  1745
# Elemento: 1048  de  1745
# Elemento: 1049  de  1745
# Elemento: 1050  de  1745
# Elemento: 1051  de  1745
# Elemento: 1052  de  1745
# Elemento: 1053  de  1745
# Elemento: 1054  de  1745
# Elemento: 1055  de  1745
# Elemento: 1056  de  1745
# Elemento: 1057  de  1745
# Elemento: 1058  de  1745
# Elemento: 1059  de  1745
# Elemento: 1060  de  1745
# Elemento: 1061  de  1745
# Elemento: 1062  de  1745
# Elemento: 1063  de  1745
# Elemento: 1064  de  1745
# Elemento: 1065  de  1745
# Elemento: 1066  de  1745
# Elemento: 1067  de  1745
# Elemento: 1068  de  1745
# Elemento: 1069  de  1745
# Elemento: 1070  de  1745
# Elemento: 1071  de  1745
# Elemento: 1072  de  1745
# Elemento: 1073  de  1745
# Elemento: 1074  de  1745
# Elemento: 1075  de  1745
# Elemento: 1076  de  1745
# Elemento: 1077  de  1745
# Elemento: 1078  de  1745
# Elemento: 1079  de  1745
# Elemento: 1080  de  1745
# Elemento: 1081  de  1745
# Elemento: 1082  de  1745
# Elemento: 1083  de  1745
# Elemento: 1084  de  1745
# Elemento: 1085  de  1745
# Elemento: 1086  de  1745
# Elemento: 1087  de  1745
# Elemento: 1088  de  1745
# Elemento: 1089  de  1745
# Elemento: 1090  de  1745
# Elemento: 1091  de  1745
# Elemento: 1092  de  1745
# Elemento: 1093  de  1745
# Elemento: 1094  de  1745
# Elemento: 1095  de  1745
# Elemento: 1096  de  1745
# Elemento: 1097  de  1745
# Elemento: 1098  de  1745
# Elemento: 1099  de  1745
# Elemento: 1100  de  1745
# Elemento: 1101  de  1745
# Elemento: 1102  de  1745
# Elemento: 1103  de  1745
# Elemento: 1104  de  1745
# Elemento: 1105  de  1745
# Elemento: 1106  de  1745
# Elemento: 1107  de  1745
# Elemento: 1108  de  1745
# Elemento: 1109  de  1745
# Elemento: 1110  de  1745
# Elemento: 1111  de  1745
# Elemento: 1112  de  1745
# Elemento: 1113  de  1745
# Elemento: 1114  de  1745
# Elemento: 1115  de  1745
# Elemento: 1116  de  1745
# Elemento: 1117  de  1745
# Elemento: 1118  de  1745
# Elemento: 1119  de  1745
# Elemento: 1120  de  1745
# Elemento: 1121  de  1745
# Elemento: 1122  de  1745
# Elemento: 1123  de  1745
# Elemento: 1124  de  1745
# Elemento: 1125  de  1745
# Elemento: 1126  de  1745
# Elemento: 1127  de  1745
# Elemento: 1128  de  1745
# Elemento: 1129  de  1745
# Elemento: 1130  de  1745
# Elemento: 1131  de  1745
# Elemento: 1132  de  1745
# Elemento: 1133  de  1745
# Elemento: 1134  de  1745
# Elemento: 1135  de  1745
# Elemento: 1136  de  1745
# Elemento: 1137  de  1745
# Elemento: 1138  de  1745
# Elemento: 1139  de  1745
# Elemento: 1140  de  1745
# Elemento: 1141  de  1745
# Elemento: 1142  de  1745
# Elemento: 1143  de  1745
# Elemento: 1144  de  1745
# Elemento: 1145  de  1745
# Elemento: 1146  de  1745
# Elemento: 1147  de  1745
# Elemento: 1148  de  1745
# Elemento: 1149  de  1745
# Elemento: 1150  de  1745
# Elemento: 1151  de  1745
# Elemento: 1152  de  1745
# Elemento: 1153  de  1745
# Elemento: 1154  de  1745
# Elemento: 1155  de  1745
# Elemento: 1156  de  1745
# Elemento: 1157  de  1745
# Elemento: 1158  de  1745
# Elemento: 1159  de  1745
# Elemento: 1160  de  1745
# Elemento: 1161  de  1745
# Elemento: 1162  de  1745
# Elemento: 1163  de  1745
# Elemento: 1164  de  1745
# Elemento: 1165  de  1745
# Elemento: 1166  de  1745
# Elemento: 1167  de  1745
# Elemento: 1168  de  1745
# Elemento: 1169  de  1745
# Elemento: 1170  de  1745
# Elemento: 1171  de  1745
# Elemento: 1172  de  1745
# Elemento: 1173  de  1745
# Elemento: 1174  de  1745
# Elemento: 1175  de  1745
# Elemento: 1176  de  1745
# Elemento: 1177  de  1745
# Elemento: 1178  de  1745
# Elemento: 1179  de  1745
# Elemento: 1180  de  1745
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# c:\program files\python37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         try:
# --> 344             self._validate_conn(conn)
#     345         except (SocketTimeout, BaseSSLError) as e:
#
# c:\program files\python37\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     842         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 843             conn.connect()
#     844
#
# c:\program files\python37\lib\site-packages\urllib3\connection.py in connect(self)
#     369             server_hostname=server_hostname,
# --> 370             ssl_context=context)
#     371
#
# c:\program files\python37\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password)
#     354         if HAS_SNI and server_hostname is not None:
# --> 355             return context.wrap_socket(sock, server_hostname=server_hostname)
#     356
#
# c:\program files\python37\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     411             context=self,
# --> 412             session=session
#     413         )
#
# c:\program files\python37\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     852                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 853                     self.do_handshake()
#     854             except (OSError, ValueError):
#
# c:\program files\python37\lib\ssl.py in do_handshake(self, block)
#    1116                 self.settimeout(None)
# -> 1117             self._sslobj.do_handshake()
#    1118         finally:
#
# SSLError: [SSL: SSLV3_ALERT_BAD_RECORD_MAC] sslv3 alert bad record mac (_ssl.c:1056)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# c:\program files\python37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# c:\program files\python37\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=77QJe0ucvYrpdiRNup3cmY (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_BAD_RECORD_MAC] sslv3 alert bad record mac (_ssl.c:1056)')))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# <ipython-input-12-ffe818cd78e6> in <module>
#       6     inicio = paginas()
#       7     canciones = musical(inicio)
# ----> 8     informacion = caracteristicas(canciones)
#       9     modelfix = modeloreja(informacion)
#      10     dendograma = dendo(modelfix)
#
# <ipython-input-4-f99ce6a7ee9a> in caracteristicas(dfinal)
#      33     n=0
#      34     for ide in dfinal['track.id']:
# ---> 35         elemento = spotify.audio_features(ide)
#      36         anexado = pd.DataFrame(elemento[0].values())
#      37         anexado = anexado.T
#
# c:\program files\python37\lib\site-packages\spotipy\client.py in audio_features(self, tracks)
#     824         if isinstance(tracks, str):
#     825             trackid = self._get_id('track', tracks)
# --> 826             results = self._get('audio-features/?ids=' + trackid)
#     827         else:
#     828             tlist = [self._get_id('track', t) for t in tracks]
#
# c:\program files\python37\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# c:\program files\python37\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# c:\program files\python37\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# c:\program files\python37\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# c:\program files\python37\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='api.spotify.com', port=443): Max retries exceeded with url: /v1/audio-features/?ids=77QJe0ucvYrpdiRNup3cmY (Caused by SSLError(SSLError(1, '[SSL: SSLV3_ALERT_BAD_RECORD_MAC] sslv3 alert bad record mac (_ssl.c:1056)')))
